# %% [markdown]
# <a href="https://colab.research.google.com/github/rumeysao/kerasilederinogrenme/blob/main/Veri_bilimi_i%C3%A7in_analiz_ve_g%C3%B6rselle%C5%9Ftirme.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Veri bilimi

# %%
import numpy as np
from matplotlib import pyplot as plt
#Matplotlib, Python'da 2 ve 3 boyutlu çiziler ve görselleştirmeler yapmamıza 
destek veren kütüphanedir.

# %%
ys= 50+ np.random.randn(50)
x = [x for x in range (len(ys))]

plt.plot(x, ys, '*')
plt.fill_between(x, ys, 45, where = (ys>45), facecolor = 'm', alpha =0.5) 
#plt.fill doldurma işlemi

plt.title("örnek gösterim")
plt.show()

# %%
# load an example dataset
from vega_datasets import data
cars = data.cars()

# plot the dataset, referencing dataframe column names
import altair as alt
alt.Chart(cars).mark_bar().encode(
  x=alt.X('Miles_per_Gallon', bin=True),
  y='count()',
  color='Origin'
)
# Out:
# alt.Chart(...)

# %%
# load an example dataset
from vega_datasets import data
cars = data.cars()

# plot the dataset, referencing dataframe column names
import altair as alt
alt.Chart(cars).mark_bar().encode(
  x='mean(Miles_per_Gallon)',
  y='Origin',
  color='Origin'
)
# Out:
# alt.Chart(...)

# %%
# load an example dataset
from vega_datasets import data
cars = data.cars()

# plot the dataset, referencing dataframe column names
import altair as alt
alt.Chart(cars).mark_bar().encode(
  x=alt.X('Miles_per_Gallon', bin=True),
  y='count()',
)
# Out:
# alt.Chart(...)

# %%
from google.colab import drive #kimlik doğrulama işlemi
drive.mount('/gdrive')
# Out:
# Mounted at /gdrive

# %%
# %cd /gdrive  #drive içinde çalışma ortamı sağlıyoruz
# Out:
# /gdrive

# %%
# !ls # neredeyim
# Out:
# MyDrive

# %%
#!ls "/gdrive/My Drive/proje/" 
import os 
os.chdir("/gdrive/My Drive/proje/")

# %%
# !ls
# Out:
# train

# %% [markdown]
# ### kütüphane kurulumları

# %%
# !pip install -q keras 
import keras

# %%
# !apt-get install graphviz -y
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# graphviz is already the newest version (2.40.1-2).
# 0 upgraded, 0 newly installed, 0 to remove and 15 not upgraded.

# %% [markdown]
# ### GPU özelliklerinin görüntülenmesi

# %%
import tensorflow as tf
tf.test.gpu_device_name()
# Out:
# '/device:GPU:0'

# %%
import tensorflow_hub as hub

# %%
print("TF version:", tf.__version__)
print("HUB version", hub.__version__)
print("GPU is ", "available" if tf.test.is_gpu_available() else  "not available")
# Out:
# TF version: 2.4.1
# HUB version 0.11.0
# WARNING:tensorflow:From <ipython-input-4-356c57766a0d>:3: is_gpu_available (from tensorflow.python.framework.test_util) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.config.list_physical_devices('GPU')` instead.
# GPU is  available

# %%
from tensorflow.python.client import device_lib
device_lib.list_local_devices()
# Out:
# [name: "/device:CPU:0"
#  device_type: "CPU"
#  memory_limit: 268435456
#  locality {
#  }
#  incarnation: 14395583985540082605, name: "/device:GPU:0"
#  device_type: "GPU"
#  memory_limit: 14638920512
#  locality {
#    bus_id: 1
#    links {
#    }
#  }
#  incarnation: 464361054270393180
#  physical_device_desc: "device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5"]

# %%
#!kill -9 -1 --> yaptığımız tüm işlemleri siliyor
